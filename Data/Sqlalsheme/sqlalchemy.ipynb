# %%
from sqlalchemy import create_engine
import sqlite3
import sqlalchemy
import os
import pandas as pd
import glob as gg

# %%
engine=create_engine('sqlite:///Users/hindsalem/Desktop/DB.db',echo=False)
conn =sqlite3.connect('//Users/hindsalem/Desktop/DB.db')

# %%
x=pd.read_sql('SELECT * FROM new_train',conn)

# %%
final_dataset=pd.read_sql("SELECT age,job,marital,education,housing,loan,contact,month,day_of_week,duration,campaign,pdays,previous,poutcome,Target FROM new_train UNION ALL SELECT age,job,marital,education,housing,loan,contact,month,day_of_week,duration,campaign,pdays,previous,poutcome,subscribed FROM bank_marketing_dataset;",conn);
final_dataset
# Out:
#        age           job   marital            education housing loan  \
# 0       49   blue-collar   married             basic.9y      no   no
# 1       37  entrepreneur   married    university.degree      no   no
# 2       78       retired   married             basic.4y      no   no
# 3       36        admin.   married    university.degree     yes   no
# 4       59       retired  divorced    university.degree      no   no
# ...    ...           ...       ...                  ...     ...  ...
# 74133   73       retired   married  professional.course     yes   no
# 74134   46   blue-collar   married  professional.course      no   no
# 74135   56       retired   married    university.degree     yes   no
# 74136   44    technician   married  professional.course      no   no
# 74137   74       retired   married  professional.course     yes   no
#
#          contact month day_of_week  duration  campaign  pdays  previous  \
# ...

# %%
final_dataset.to_csv('Bank_Dataset.csv')

# %%
final_dataset
